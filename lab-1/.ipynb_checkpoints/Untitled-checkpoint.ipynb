# %%
import cv2

# %%
flower = cv2.imread('./flower.png')

# %%
cv2.imshow('Flower Image', flower)

# %%
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %%
type(flower)
# Out:
# numpy.ndarray

# %%
print(flower)
# Out:
# [[[ 87  87  87]
#   [ 87  87  87]
#   [ 86  86  86]
#   ...
#   [104 104 104]
#   [105 105 105]
#   [107 107 107]]
#
#  [[ 87  87  87]
#   [ 87  87  87]
#   [ 87  87  87]
#   ...
#   [104 104 104]
#   [105 105 105]
#   [106 106 106]]
#
#  [[ 87  87  87]
#   [ 87  87  87]
#   [ 87  87  87]
#   ...
#   [104 104 104]
#   [105 105 105]
#   [105 105 105]]
#
#  ...
#
#  [[ 71  71  71]
#   [ 71  71  71]
#   [ 72  72  72]
#   ...
#   [ 90  90  90]
#   [ 70  70  70]
#   [136 136 136]]
#
#  [[ 71  71  71]
#   [ 71  71  71]
#   [ 71  71  71]
#   ...
#   [ 70  70  70]
#   [134 134 134]
#   [111 111 111]]
#
#  [[ 71  71  71]
#   [ 71  71  71]
#   [ 71  71  71]
#   ...
#   [134 134 134]
#   [110 110 110]
#   [ 91  91  91]]]

# %%
flower[0,0]
# Out:
# array([87, 87, 87], dtype=uint8)

# %%
flower.shape
# Out:
# (318, 396, 3)

# %%
cv2.imwrite('flower-copy.png',flower)
# Out:
# True

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(flower)

# %%
image_c = cv2.imread("./red_bird.png",cv2.IMREAD_COLOR)

# %%
image_rgb = cv2.cvtColor(image_c, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb,cmap="gray")

# %%
plt.axis("off")
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %%
plt.imshow(image_c,cmap="gray")

# %%
cv2.resize(flower,(200,200))
# Out:
# array([[[ 87,  87,  87],
#         [ 86,  86,  86],
#         [ 88,  88,  88],
#         ...,
#         [105, 105, 105],
#         [104, 104, 104],
#         [106, 106, 106]],
#
#        [[ 87,  87,  87],
#         [ 87,  87,  87],
#         [ 88,  88,  88],
#         ...,
#         [106, 106, 106],
#         [104, 104, 104],
#         [105, 105, 105]],
#
#        [[ 87,  87,  87],
#         [ 88,  88,  88],
#         [ 88,  88,  88],
#         ...,
#         [106, 106, 106],
#         [107, 107, 107],
#         [106, 106, 106]],
#
#        ...,
#
#        [[ 71,  71,  71],
#         [ 72,  72,  72],
#         [ 73,  73,  73],
#         ...,
#         [ 89,  89,  89],
#         [113, 113, 113],
#         [ 89,  89,  89]],
#
#        [[ 71,  71,  71],
#         [ 72,  72,  72],
#         [ 72,  72,  72],
#         ...,
#         [110, 110, 110],
#         [ 93,  93,  93],
#         [106, 106, 106]],
#
#        [[ 71,  71,  71],
#         [ 71,  71,  71],
#         [ 71,  71,  71],
# ...

# %%
flower_resize = cv2.resize(flower,(200,200))

# %%
plt.imshow(flower_resize)

# %%
r,g,b = cv2.split(flower)

# %%
plt.imshow(r,cmap="gray")

# %%
plt.imshow(g)

# %%
plt.imshow(b)

# %%
blue_channel, green_channel, red_channel = cv2.split(image_rgb)

cv2.imshow('Blue Channel', blue_channel)
cv2.imshow('Green Channel', green_channel)
cv2.imshow('Red Channel', red_channel)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.merge([blue_channel,green_channel,red_channel])

# %%
plt.imshow(img)

# %%
import numpy as np

# %%
b, g, r = cv2.split(image_c)
zeros = np.zeros(image_c.shape[:2], dtype='uint8')
cv2.imshow('Blue Channel Only', cv2.merge([b, zeros, zeros]))
cv2.imshow('Green Channel Only', cv2.merge([zeros, g, zeros]))
cv2.imshow('Red Channel Only', cv2.merge([zeros, zeros, r]))

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_c_gray = cv2.cvtColor(image_c,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image_c_gray)

# %%
for i, col in enumerate(color):
hist=cv2.calcHist([image_color], [i], None, [256], [0,256])
plt.plot(hist, color=col)
