# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def OpenImage(path):
    I = cv2.imread(path)
    if I is None:
        raise FileNotFoundError("")
    L, C = I.shape[:2]
    return I, L, C

# %%
def Divide(I):
    if len(I.shape) == 3:
        B, G, R = cv2.split(I)
        return B, G, R

# %%
def HSV(I):
    return cv2.cvtColor(I, cv2.COLOR_BGR2HSV)

# %%
def CountPix(I):
    L, C = I.shape[:2]
    N = L * C
    return N

# %%
def FactPix(I, alpha, beta):
    new_image = cv2.convertScaleAbs(I, alpha=alpha, beta=beta)
    return new_image

# %%
def ViewImage(I):
    if I is None:
        print(f"Error: Could not find image at {path}")
        return
    cv2.imshow("My Image Viewer", I)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import numpy as np

def Func_a(image):
    img = image.astype(np.float32)

    log_img = np.log1p(img)
    exp_img = np.exp(img / 255)
    square_img = np.square(img)
    sqrt_img = np.sqrt(img)

    return log_img, exp_img, square_img, sqrt_img

# %%
def Func_m(image):
    mu = np.mean(image)
    sigma = np.std(image)
    return mu, sigma

# %%
def Normalize(image, a, b):
    norm = cv2.normalize(image, None, a, b, cv2.NORM_MINMAX)
    return norm

# %%
def Inverse(image):
    Inv = 255 - image
    return Inv

# %%
def CalcHist(image):
    H = cv2.calcHist([image], [0], None, [256], [0,256])
    b = np.arange(256)
    return H, b

# %%
def Threshold(image, s):
    _, T = cv2.threshold(image, s, 255, cv2.THRESH_BINARY)
    return T

# %%
def Func_j(path):
    img = cv2.imread(path, 0)

    plt.imshow(img, cmap="gray")
    plt.title("Original Image")
    plt.show()

    H, _ = CalcHist(img)
    plt.plot(H)
    plt.title("Original Histogram")
    plt.show()

    inv = Inverse(img)

    plt.imshow(inv, cmap="gray")
    plt.title("Inverse Image")
    plt.show()

    H2, _ = CalcHist(inv)
    plt.plot(H2)
    plt.title("Histogram After Inverse")
    plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def Func_t(path):
    img = cv2.imread(path, 0)

    plt.figure()
    plt.imshow(img, cmap="gray")
    plt.title("Original Image")
    plt.show()

    H1, b1 = CalcHist(img)
    plt.figure()
    plt.plot(b1, H1)
    plt.title("Histogram - Original")
    plt.show()

    norm = Normalize(img, 10, 50)

    plt.figure()
    plt.imshow(norm, cmap="gray")
    plt.title("Normalized Image [10,50]")
    plt.show()

    H2, b2 = CalcHist(norm)
    plt.figure()
    plt.plot(b2, H2)
    plt.title("Histogram - Normalized")
    plt.show()

    return img, norm

# %%
car = cv2.imread('./car.png')

# %%
car.shape
# Out:
# (133, 301, 3)

# %%
OpenImage('./car.png')
# Out:
# (array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [255, 255, 255]],
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [255, 255, 255]],
#
#         [[254, 254, 254],
# ...

# %%
Divide(car)
# Out:
# (array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [254, 254, 254, ..., 254, 254, 255],
#         [254, 254, 254, ..., 254, 254, 255],
#         [254, 254, 254, ..., 254, 254, 255]], shape=(133, 301), dtype=uint8),
#  array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [254, 254, 254, ..., 254, 254, 255],
#         [254, 254, 254, ..., 254, 254, 255],
#         [254, 254, 254, ..., 254, 254, 255]], shape=(133, 301), dtype=uint8),
#  array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [254, 254, 254, ..., 254, 254, 255],
#         [254, 254, 254, ..., 254, 254, 255],
#         [254, 254, 254, ..., 254, 254, 255]], shape=(133, 301), dtype=uint8))

# %%
ViewImage(HSV(car))

# %%
CountPix(car)
# Out:
# 40033

# %%
ViewImage(FactPix(car,0.8,0.1))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Définition de la matrice I (4x4)
I = np.array([
    [128, 128,   0, 255],
    [128,   0,   0, 255],
    [  0, 128,   0, 255],
    [128, 128,   0, 255]
], dtype=np.uint8)

# Visualisation
plt.imshow(I, cmap='gray', vmin=0, vmax=255)
plt.title("Visualisation de la matrice I")
plt.colorbar()
plt.show()

# %%
taille = (512, 512)
moyenne = 128
ecart_type = np.random.uniform(10, 50)

ran_dN = moyenne + ecart_type * np.random.randn(*taille)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(ran_dN, cmap='gray', vmin=0, vmax=255)
plt.title(f"Image Aléatoire (std={ecart_type:.2f})")

plt.subplot(1, 2, 2)
plt.hist(ran_dN.ravel(), bins=256, range=(0, 255), color='gray', alpha=0.7)
plt.title("Histogramme (Loi Normale)")
plt.show()
